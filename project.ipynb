# %% [markdown]
# # Fundamentals of Data Analysis Project

# %% [markdown]
# **Neil Anglim**
# ***

# %% [markdown]
# ## Imports

# %% [markdown]
# First things first, we are going to load in the dataset, which is kindly provided within the seaborn library. And we are also going to load in additional libraries. All libraries will be loaded here at the same time for clarity.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os


iris = sns.load_dataset('iris')
plt.style.use('ggplot')

# %% [markdown]
# ---
# # Introduction

# %% [markdown]
# ---
# ## Project brief
# ---

# %% [markdown]
# - The project is to create a notebook investigating the variables and data points within the well-known iris flower data set associated with Ronald A Fisher.
# - In the notebook, you should discuss the classification of each variable within the data set according to common variable types and scales of measurement in mathematics, statistics, and Python.
# - Select, demonstrate, and explain the most appropriate summary statistics to describe each variable.
# - Select, demonstrate, and explain the most appropriate plot(s) for each variable.
# - The notebook should follow a cohesive narrative about the data set.
#
# ---

# %% [markdown]
# The Iris dataset is a well-known and oft-cited dataset in the field of machine learning and statistics. It was introduced by British statistician and biologist Ronal Fisher in 1936 as an example of linear discriminant analysis. The  dataset  consists of measurements from three distinct species of Iris flower: [*Iris setosa*](https://en.wikipedia.org/wiki/iris_setosa), [*Iris virginica*](https://en.wikipedia.org/wiki/Iris_virginica), and [*Iris versicolor*](https://en.wikipedia.org/wiki/Iris_versicolor), seen below in the same order.
#
# <div style="display: flex; flex-direction: row; justify-content: center;">
#     <img src="./img/setosa.jpg" alt="Iris setosa" width="275" height="250" style="margin: 10px;">
#     <img src="./img/virginica.jpg" alt="Iris virginica" width="275" height="250" style="margin: 10px;">
#     <img src="./img/versicolor.jpg" alt="Iris versicolor" width="275" height="250" style="margin: 10px;">
# </div>
#
# Each observation in the Iris dataset represents a flower and includes four variables:
#
# 1. Sepal length (in centimeters)
# 2. Sepal width (in centimeters)
# 3. Petal length (in centimeters)
# 4. Petal width (in centimeters)
#
# The Iris dataset is frequently used as a benchmark dataset of machine learning and serves as an introductory example in the teaching of data analysis and pattern recognition due to its small size. It is considered one of the best known databases in pattern recognition literature, and is likened to the "Hello World" of Data Analysis by [GeeksforGeeks](https://www.geeksforgeeks.org/python-basics-of-pandas-using-iris-dataset/).

# %% [markdown]
# ---
# ## Loading and understanding the dataset

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# Below are some small functions, implemented to ensure the dataset is loading correctly, inspired from this [website](https://www.tutorialspoint.com/exploratory-data-analysis-on-iris-dataset).

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ---
# # Variable Types & Scales of Measurement

# %% [markdown]
# Numerical variables:
# Sepal Length, Sepal Width, Petal Length, Petal Width:
# - These represent continuous measurements of different parts of the iris flowers. They are on a ratio scale (being measured in centimetres), allowing for precise comparisons and calculations due to the presence of a true zero point.
# - They will be represented in Python using floating point numbers (**float**); as they have decimal points, which can be seen in the above section where they are loaded in. They could also be represented using integers (**int**), but floating-point numbers are a more appropriate choice to capture the precision of the measurements within the dataset accurately.
#
#
# Categorical variable:
# Species:
# - This variable categorizes the flowers in the dataset into three distinct classes; *Iris setosa*, *Iris virginica* and *Iris versicolor*. As a categorical variable, it lacks inherent order or magnitude between its classes and is used primarily for classification purposes.
# - These are represented using strings (**str**) or objects in Python.

# %% [markdown]
# ---
# # Summary Statistics for each variable

# %% [markdown]
# ## Numerical

# %%
summary_stats = iris.groupby('species').describe()
print(summary_stats)
# Out:
#            sepal_length                                              \
#                   count   mean       std  min    25%  50%  75%  max
# species
# setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#            sepal_width         ... petal_length      petal_width         \
#                  count   mean  ...          75%  max       count   mean
# species                        ...
# setosa            50.0  3.428  ...        1.575  1.9        50.0  0.246
# versicolor        50.0  2.770  ...        4.600  5.1        50.0  1.326
# virginica         50.0  2.974  ...        5.875  6.9        50.0  2.026
#
#
#                  std  min  25%  50%  75%  max
# species
# setosa      0.105386  0.1  0.2  0.2  0.3  0.6
# versicolor  0.197753  1.0  1.2  1.3  1.5  1.8
# virginica   0.274650  1.4  1.8  2.0  2.3  2.5
#
# ...

# %% [markdown]
# Sepal Length:
# - Setosa: The mean sepal length for the setosa species is approximately 5.006, with a standard deviation of around 0.352. The lengths vary between 4.3 and 5.8, with 75% of the lengths falling below 5.2.
# - Versicolor: Versicolor species have a mean sepal length of roughly 5.936, showing slightly higher variability (standard deviation of 0.516). The lengths range from 4.9 to 7.0, with 75% of lengths below 6.3.
# - Virginica: This species exhibits the longest sepal lengths, with a mean of about 6.588 and a standard deviation of 0.636. Sepals range from 4.9 to 7.9, with 75% of lengths below 6.9.

# %% [markdown]
# Sepal Width:
# - Setosa: Setosa has a mean sepal width of approximately 3.428, with a standard deviation of about 0.379. Widths vary between 2.3 and 4.4, with 75% below 3.675.
# - Versicolor: Versicolor species show a mean sepal width of around 2.770, with a standard deviation of 0.314. Widths range from 2.0 to 3.4, with 75% below 3.0.
# - Virginica: Virginica species exhibit a mean sepal width of roughly 2.974, with a standard deviation of about 0.322. Widths vary between 2.2 and 3.8, with 75% below 3.175.

# %% [markdown]
# Petal Length:
# - Setosa: The mean petal length for setosa is about 1.462, with a standard deviation of approximately 0.174. Lengths range from 1.0 to 1.9, with 75% below 1.575.
# - Versicolor: Versicolor species have a mean petal length of around 4.260, with a standard deviation of 0.469. Lengths range from 3.0 to 5.1, with 75% below 4.6.
# - Virginica: Virginica species exhibit the longest petal lengths, with a mean of roughly 5.552 and a standard deviation of about 0.551. Petals range from 4.5 to 6.9, with 75% below 5.875.

# %% [markdown]
# Petal Width:
# - Setosa: Setosa species have a mean petal width of approximately 0.246, with a standard deviation of around 0.105. Widths range from 0.1 to 0.6, with 75% below 0.3.
# - Versicolor: Versicolor species show a mean petal width of about 1.326, with a standard deviation of 0.198. Widths vary from 1.0 to 1.8, with 75% below 1.5.
# - Virginica: Virginica species exhibit a mean petal width of roughly 2.026, with a standard deviation of about 0.274. Widths range from 1.4 to 2.5, with 75% below 2.3.

# %% [markdown]
# ---
# ## Categorical

# %% [markdown]
# Summary statistics for categorical variables would be unique values, count, and mode.
# In the case of the Iris dataset; there is no unique values and the count is evenly spread with 50 entries for each of the three different species, this also means there is little insight to be gained from calculating the mode.
#
# Nonetheless, it is important to appreciate that calculating these is useful in different scenarios where there might be an uneven distribution. It would help to identify the most prevalent category in the dataset.
# However, for this project, it serves no purpose.

# %% [markdown]
# Check unique values in the 'species' column

# %%
species_counts = iris['species'].value_counts()

# %% [markdown]
# Display summary statistics

# %%
species_counts
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ---
# # Plots for each variable

# %% [markdown]
# ## Primary visualisations

# %% [markdown]
# First, we will look at different [Seaborn](https://seaborn.pydata.org/) style plots to determine the most suitable, and save images using [Matplotlib](https://chartio.com/resources/tutorials/how-to-save-a-plot-to-a-file-using-matplotlib/).

# %% [markdown]
# ### Sepal Length

# %%
folder_path = 'img'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# %%
# Create a box plot for Sepal Length
plt.figure(figsize=(5, 5))  # Set figure size
sns.boxplot(x='species', y='sepal_length', data=iris)
plt.title('Box Plot of Sepal Length by Species')
plt.xlabel('Species')
plt.ylabel('Sepal Length')
plt.tight_layout()
file_path = os.path.join(folder_path, 'box_seplen.png')
plt.savefig(file_path)

# %%
def plot_violin_and_save(iris, variable, folder_path='img'):
    """
    Create a violin plot for a specified variable across different species in the Iris dataset
    and save the plot as an image.

    Parameters:
    - iris: DataFrame, input Iris dataset
    - variable: str, name of the variable to plot ('sepal_length', 'sepal_width', 'petal_length', 'petal_width')
    - folder_path: str, optional, folder path to save the image (default is 'img')
    """
    # Create the folder if it doesn't exist
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
    
    # Set figure size
    plt.figure(figsize=(5, 5))
    
    # Plot violin plot
    sns.violinplot(x='species', y=variable, data=iris)
    
    # Set title and labels
    plt.title(f'Violin Plot of {variable.replace("_", " ").title()} by Species')
    plt.xlabel('Species')
    plt.ylabel(variable.replace("_", " ").title())
    
    plt.tight_layout()
    
    # Save the plot
    file_path = os.path.join(folder_path, f'violinplot_{variable}.png')
    plt.savefig(file_path)
    
    plt.show()  # Show the plot

# %%
plot_violin_and_save(iris, 'sepal_length')

# %%
plt.figure(figsize=(5, 5))  # Set figure size
sns.histplot(data=iris, x='sepal_length', hue='species', kde=True)
plt.title('Histogram of Sepal Length by Species')
plt.xlabel('Sepal Length')
plt.ylabel('Frequency')

file_path = os.path.join(folder_path, 'hist_seplen.png')
plt.savefig(file_path)

# %% [markdown]
# ### Sepal Width

# %%
# a violin plot for Sepal Width
plot_violin_and_save(iris, 'sepal_width')

# %% [markdown]
# ### Petal Length

# %%
plot_violin_and_save(iris, 'petal_length')

# %% [markdown]
# ### Petal Width

# %%
plot_violin_and_save(iris, 'petal_width')

# %%
sns.pairplot(iris, hue='species', palette='flare', height=2.5)
plt.savefig(os.path.join(folder_path, 'pairplot.png'))
# Out:
# c:\Users\neilj\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ---
# ## Key Findings

# %% [markdown]
# For the scope of this project, violin plots appear to offer a more advantageous representation. Here is an image from a [blog](https://mode.com/blog/violin-plot-examples) detailing how to read them.

# %% [markdown]
# <div>
# <img src="./img/readingviolins.png" alt="readviolins" width="400" height=400" style="margin: 1px;">
# </div>

# %% [markdown]
# Violins provide a superior visual depiction of value distribution compared to Box Plots, aiding in a more profound comprehension of Sepal Length variability across species. This is clearly evident in the accompanying images below. Image representation inspired by [MarkdownMonster](https://medium.com/markdown-monster-blog/getting-images-into-markdown-documents-and-weblog-posts-with-markdown-monster-9ec6f353d8ec).

# %% [markdown]
# The same can be said for histograms. While effective for displaying frequency distributions of individual variables, they are not as useful in cross species comparisons. They lack the ability to showcase the shape, concentration and probability density in the same meaningful way.

# %% [markdown]
# ### Sepal Length

# %% [markdown]
# ![img](./img/box_seplen.png)![img](./img/hist_seplen.png)

# %% [markdown]
# ![img](./img/violinplot_sepal_length.png)

# %% [markdown]
# ### Sepal Width

# %% [markdown]
# Observing the below violins allows comparison between the Sepal Width distribution among species.

# %% [markdown]
# Although the plots for sepal length might lead one to expect that setosa is the obviously smaller flower on average, looking at the sepal width changes this.

# %% [markdown]
# ![img](./img/violinplot_sepal_width.png)

# %% [markdown]
# ### Petal Length & Width

# %% [markdown]
# ![img](./img/violinplot_petal_length.png) ![img](./img/violinplot_petal_width.png)

# %% [markdown]
# These images further reinforce how setosa can be easily separated from the other flowers.

# %% [markdown]
# If we look at the pairplot below, see that the setosa species can be easily separated from the other two. Comparison of the variables on a Seaborn pairplot allows for a great insight into the relationships between variables.

# %% [markdown]
# ![img](./img/pairplot.png)

# %% [markdown]
# ### Correlation

# %% [markdown]
# The below correlation was partially inspired by this blog on the Medium [website](https://medium.com/@szabo.bibor/how-to-create-a-seaborn-correlation-heatmap-in-python-834c0686b88e)

# %%
#drop species column and calculate correlation matrix
correlation_matrix = iris.drop('species', axis=1).corr()

# Create a heatmap to visualize the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix of Iris Dataset Variables')
plt.show()

# %% [markdown]
# The above correlation matrix represents the correlation coefficients between different variables for the entire dataset.
# - Sepal length has a strong positive correlation with both petal length (0.872) and petal width (0.818). These values indicate a tendency for sepal length to increase as petal length and width increase.
#
# - Sepal width shows weak negative correlations with petal length (-0.428) and petal width (-0.366). This implies that as sepal width increases, there's a tendency for petal length and width to decrease slightly.
#
# - Petal length exhibits a strong positive correlation with petal width (0.963). This suggests that as petal length increases, there's a strong tendency for petal width to increase as well.

# %% [markdown]
# If we do correlation matrices for each species independently, it will be much more meaningful in the context of each species.

# %%
# Create separate correlation matrices for each species
species_list = iris['species'].unique()

for species in species_list:
    species_data = iris[iris['species'] == species]
    correlation_matrix = species_data.drop('species', axis=1).corr() # Drop the 'species' column and calculate the correlation matrix
    plt.figure(figsize=(5, 5))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
    plt.title(f'Correlation Matrix Heatmap of {species} Species')
    print(f"Correlation matrix for {species} species:")
    print(correlation_matrix)
    # print("\n")
# Out:
# Correlation matrix for setosa species:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000     0.742547      0.267176     0.278098
# sepal_width       0.742547     1.000000      0.177700     0.232752
# petal_length      0.267176     0.177700      1.000000     0.331630
# petal_width       0.278098     0.232752      0.331630     1.000000
# Correlation matrix for versicolor species:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000     0.525911      0.754049     0.546461
# sepal_width       0.525911     1.000000      0.560522     0.663999
# petal_length      0.754049     0.560522      1.000000     0.786668
# petal_width       0.546461     0.663999      0.786668     1.000000
# Correlation matrix for virginica species:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000     0.457228      0.864225     0.281108
# ...

# %% [markdown]
# ### Setosa

# %% [markdown]
# - Sepal length exhibits a strong positive correlation with sepal width (0.743). This implies that as sepal length increases, there's a tendency for sepal width to increase as well.
# - Petal length has a relatively weak positive correlation with petal width (0.332), suggesting a moderate relationship between these two variables in the setosa species.
# - Sepal length has a very weak positive correlation with petal length (0.267) and petal width (0.278), suggesting little relationship between them.

# %% [markdown]
# ### Versicolor

# %% [markdown]
# - Sepal length has a moderately strong positive correlation with petal length (0.754) and a moderate positive correlation with petal width (0.546). This indicates that as sepal length increases, petal length and width also tend to increase, although not as strongly.
#
# - Sepal width shows a moderate positive correlation with petal width (0.664) and a moderate correlation with petal length (0.561). As sepal width increases, there is a tendency for petal width and length to increase, but the relationship is not as strong as with sepal length.
#
# - Petal length demonstrates a strong positive correlation with petal width (0.787), indicating that as petal length increases, petal width also tends to increase significantly.

# %% [markdown]
# ### Virginica

# %% [markdown]
# - Sepal length exhibits a strong positive correlation with petal length (0.864) and a weak correlation with sepal width (0.457). This suggests that as sepal length increases, there's a tendency for petal length to increase considerably, while the relationship with sepal width is less pronounced.
#
# - Sepal width has a moderate positive correlation with petal width (0.538) and a weak correlation with petal length (0.401). As sepal width increases, there's a tendency for petal width to increase moderately, but the correlation with petal length is not as strong.
#
# - Petal length demonstrates a strong positive correlation with sepal length (0.864) and a moderate positive correlation with sepal width (0.401). This indicates that as petal length increases, sepal length and width tend to increase, although the correlation with sepal width is not as strong.
#
# - Petal width has a weak correlation with sepal length (0.281) and sepal width (0.538), and a very weak correlation with petal length (0.322). This suggests a less pronounced relationship between petal width and sepal characteristics compared to the relationship between petal length and sepal characteristics.

# %% [markdown]
# ---
# # Conclusion

# %% [markdown]
# This investigation thoroughly explores the renowned Iris flower dataset associated with Ronald A Fisher, covering variable classification, summary statistics, visualizations, and correlation insights. The project effectively meets the outlined objectives, revealing fundamental dataset attributes.
#
# **Variable Classification & Measurement Scales:**
# The dataset features numerical variables (Sepal Length, Sepal Width, Petal Length, Petal Width) on a ratio scale and a categorical variable (Species) primarily for classification. Numerical variables are measured in centimeters, enabling precise comparisons due to a true zero point. The categorical variable segregates the dataset into distinct species without inherent order or magnitude between classes.
#
# **Summary Statistics & Visualization:**
# Descriptive statistics like mean, standard deviation, and quartiles offer comprehensive insights into numerical variables across species. Visualizations—Box Plots, Violin Plots, Histograms, and Pair Plots—reveal variable distributions and relationships within and across species, aiding pattern recognition and analysis.
#
# **Correlation Analysis:**
# The correlation matrix uncovers notable associations between variables. Strong positive correlations exist between Sepal Length and Petal Length/Width, while Sepal Width shows weak negative correlations with Petal Length/Width. Species-specific correlation matrices uncover unique relationships for each Iris species.
#
# **Alignment with Project Brief:**
# The project meticulously fulfills the outlined objectives by exploring variable classifications, presenting summary statistics, employing diverse visualizations, and conducting comprehensive correlation analysis. The analyses exceed project expectations, providing a deep understanding of the dataset's intricacies.
#
# **Final Remarks:**
# This analysis offers a detailed exploration of variables, data relationships, and patterns within the Iris dataset. It serves as a solid foundation for further analyses or applications, meeting project goals and illustrating fundamental principles in data analysis and pattern recognition.

# %% [markdown]
# ---
# # References

# %% [markdown]
# References are listed appropriately throughout the document, see highlighted [markdown]( ).

# %% [markdown]
# ***
#
# ## End
